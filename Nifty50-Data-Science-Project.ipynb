# %%
import pandas as pd           # Data manipulation
import numpy as np            # Numerical computations
import matplotlib.pyplot as plt  # Visualization
import seaborn as sns         # Advanced visualizations
from sklearn.model_selection import train_test_split  # Data splitting
from sklearn.preprocessing import MinMaxScaler  # Scaling data
from sklearn.metrics import mean_squared_error, mean_absolute_error  # Evaluation metrics
from keras.models import Sequential  # Deep learning model (LSTM)
from keras.layers import LSTM, Dense, Dropout  # LSTM layers
import yfinance as yf  # For fetching additional stock data
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv(r"C:\Users\Akash\Documents\Jupyter\IDSE\Project\archive\NIFTY50_all.csv")

print(df.info())

# Check for missing values
print(df.isnull().sum())

# Drop columns with significant missing values or decide how to fill them
df = df.drop(columns=['Trades', 'Deliverable Volume', '%Deliverble'], axis=1)  # Dropping for simplicity

# Drop rows with any remaining NaN values (optional)
df = df.dropna()
print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235192 entries, 0 to 235191
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Date                235192 non-null  object
#  1   Symbol              235192 non-null  object
#  2   Series              235192 non-null  object
#  3   Prev Close          235192 non-null  float64
#  4   Open                235192 non-null  float64
#  5   High                235192 non-null  float64
#  6   Low                 235192 non-null  float64
#  7   Last                235192 non-null  float64
#  8   Close               235192 non-null  float64
#  9   VWAP                235192 non-null  float64
#  10  Volume              235192 non-null  int64
#  11  Turnover            235192 non-null  float64
#  12  Trades              120344 non-null  float64
#  13  Deliverable Volume  219115 non-null  float64
#  14  %Deliverble         219115 non-null  float64
# ...

# %%
print(df.head())
# Out:
#          Date      Symbol Series  Prev Close    Open     High    Low   Last  \
# 0  2007-11-27  MUNDRAPORT     EQ      440.00  770.00  1050.00  770.0  959.0
# 1  2007-11-28  MUNDRAPORT     EQ      962.90  984.00   990.00  874.0  885.0
# 2  2007-11-29  MUNDRAPORT     EQ      893.90  909.00   914.75  841.0  887.0
# 3  2007-11-30  MUNDRAPORT     EQ      884.20  890.00   958.00  890.0  929.0
# 4  2007-12-03  MUNDRAPORT     EQ      921.55  939.75   995.00  922.0  980.0
#
#     Close    VWAP    Volume      Turnover
# 0  962.90  984.72  27294366  2.687719e+15
# 1  893.90  941.38   4581338  4.312765e+14
# 2  884.20  888.09   5124121  4.550658e+14
# 3  921.55  929.17   4609762  4.283257e+14
# 4  969.30  965.65   2977470  2.875200e+14

# %%
df['Date'] = pd.to_datetime(df['Date'])
df = df.drop(columns='Series', axis=1)

# %%
df.set_index('Date', inplace=True)

# %%
for symbol in symbols:
    symbol_df = df[df['Symbol'] == symbol]
    plt.figure(figsize=(10,5))
    plt.plot(symbol_df.index, symbol_df['Close'], label=symbol)  # Use index here instead of 'Date'
    plt.title(f'Closing Price of {symbol}')
    plt.xlabel('Date')
    plt.ylabel('Close Price')
    plt.legend()
    plt.show()

# %%
import yfinance as yf

# Fetch data for Asian Paints (ASIANPAINT.NS is the symbol for NSE)
asianpaints = yf.Ticker("ASIANPAINT.NS")

# Get historical market data
hist_data = asianpaints.history(period="max")  # Fetch all available data

# Display the data
print(hist_data.head())
# Out:
#                                 Open       High        Low      Close  Volume  \
# Date
# 2002-07-01 00:00:00+05:30  15.754284  16.565333  15.754284  16.432617   87810
# 2002-07-02 00:00:00+05:30  15.756496  16.798327  15.756496  16.604412  588615
# 2002-07-03 00:00:00+05:30  16.417866  16.810855  16.171602  16.761456  162075
# 2002-07-04 00:00:00+05:30  16.712796  17.203850  16.712796  16.933990  266625
# 2002-07-05 00:00:00+05:30  17.253246  18.432955  17.203846  17.737663  408600
#
#                            Dividends  Stock Splits
# Date
# 2002-07-01 00:00:00+05:30        0.0           0.0
# 2002-07-02 00:00:00+05:30        0.0           0.0
# 2002-07-03 00:00:00+05:30        0.0           0.0
# 2002-07-04 00:00:00+05:30        0.0           0.0
# 2002-07-05 00:00:00+05:30        0.0           0.0

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# Fetch data for Asian Paints from Yahoo Finance
asianpaints = yf.Ticker("ASIANPAINT.NS")

# Get historical data
hist_data = asianpaints.history(period="max")

# Plot the closing prices
plt.figure(figsize=(10, 5))
plt.plot(hist_data.index, hist_data['Close'], label="Asian Paints")
plt.title('Asian Paints Stock Price History')
plt.xlabel('Date')
plt.ylabel('Closing Price (INR)')
plt.legend()
plt.show()
